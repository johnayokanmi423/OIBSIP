# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
pd.read_csv(r"C:\Users\ELIAS\Desktop\Oasis infobyte\Dataset\ifood_df.csv")
df=pd.read_csv(r"C:\Users\ELIAS\Desktop\Oasis infobyte\Dataset\ifood_df.csv")

# %%
print(f"Overview of dataset")
print(f"The shape of the dataset is: {df.shape}")
null_values=df.isnull().sum().sum()
if null_values== 0:
    print("There is no null values")
else :
    print("The number of null values is {null_values}")
print(f"The number of null values: {null_values}")

print(f"Data Types: {df.dtypes}")
# Out:
# Overview of dataset
# The shape of the dataset is: (2205, 39)
# There is no null values
# The number of null values: 0
# Data Types: Income                  float64
# Kidhome                   int64
# Teenhome                  int64
# Recency                   int64
# MntWines                  int64
# MntFruits                 int64
# MntMeatProducts           int64
# MntFishProducts           int64
# MntSweetProducts          int64
# MntGoldProds              int64
# NumDealsPurchases         int64
# NumWebPurchases           int64
# NumCatalogPurchases       int64
# NumStorePurchases         int64
# NumWebVisitsMonth         int64
# AcceptedCmp3              int64
# AcceptedCmp4              int64
# AcceptedCmp5              int64
# AcceptedCmp1              int64
# AcceptedCmp2              int64
# Complain                  int64
# Z_CostContact             int64
# Z_Revenue                 int64
# Response                  int64
# Age                       int64
# ...

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
print(f"More info on the dataset: {df.info()}")
print(f"Check for the unique Values: {df.nunique()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %%
# Drop the column with a non-unique value(1);  Z_CostContact, Z_Revenue  
df.drop(columns=['Z_CostContact', 'Z_Revenue'], inplace=True )

# %%
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %% [markdown]
# ## Numerical Analysis(EDA)

# %%
color= ['red']
plt.figure(figsize=(10,6))
sns.boxplot(data= df, y= 'MntTotal', color= 'Pink')
plt.ylabel('Mnt Total')
plt.title('Boxplot of Mnt Total', fontsize=14, fontweight= 'bold')
# Out:
# Text(0.5, 1.0, 'Boxplot of Mnt Total')

# %%
#Boxplot for income
plt.figure(figsize=(10,6))
sns.boxplot(data=df, y='Income', color='Brown')
plt.title('Boxplot for Income', fontsize=14, fontweight='bold')
plt.ylabel('Income', fontsize= 14, fontweight= 'bold')
plt.show()

# %%
#Histogram for Income
plt.figure(figsize= (10,6))
sns.histplot(data=df, x='Income', kde=True, bins=30)
plt.title('Histogram of income', fontsize= 20, fontweight='bold')
plt.ylabel('Income', fontsize= 16, fontweight='bold')
plt.show()

# %%
#Create The Outliers for the Data
import pandas as pd
df=pd.read_csv(r"C:\Users\ELIAS\Desktop\Oasis infobyte\Dataset\ifood_df.csv")

Q1=df['MntTotal'].quantile(0.25)
Q2=df['MntTotal'].quantile(0.75)
IQR=Q2-Q1
Lower_bound=Q1-1.5*IQR
Upper_bound=Q2+1.5*IQR
outliers= df[(df['MntTotal']>Upper_bound) | (df['MntTotal']< Lower_bound)]
outliers.head()
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 1159  90638.0        0         0       29      1156        120
# 1467  87679.0        0         0       62      1259        172
# 1547  90638.0        0         0       29      1156        120
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 1159              915               94               144            96  ...
# 1467              815               97               148            33  ...
# 1547              915               94               144            96  ...
#
#       marital_Together  marital_Widow  education_2n Cycle  education_Basic  \
# 1159                 0              0                   0                0
# 1467                 1              0                   0                0
# 1547                 0              0                   0                0
#
#       education_Graduation  education_Master  education_PhD  MntTotal  \
# ...

# %%
df.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.histplot(data=df, x= 'Age', kde=True, bins=30)
plt.title('Histogram of Age')
plt.ylabel('Frequency')
plt.xlabel('Age')
plt.show()

# %%
#Compare the outliers
df=df[(df['MntTotal']> Upper_bound) | (df['MntTotal']<Lower_bound)]
df.describe()
# Out:
#              Income  Kidhome  Teenhome    Recency     MntWines   MntFruits  \
# count      3.000000      3.0       3.0   3.000000     3.000000    3.000000
# mean   89651.666667      0.0       0.0  40.000000  1190.333333  137.333333
# std     1708.379447      0.0       0.0  19.052559    59.467078   30.022214
# min    87679.000000      0.0       0.0  29.000000  1156.000000  120.000000
# 25%    89158.500000      0.0       0.0  29.000000  1156.000000  120.000000
# 50%    90638.000000      0.0       0.0  29.000000  1156.000000  120.000000
# 75%    90638.000000      0.0       0.0  45.500000  1207.500000  146.000000
# max    90638.000000      0.0       0.0  62.000000  1259.000000  172.000000
#
#        MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# count         3.000000         3.000000          3.000000      3.000000  ...
# mean        881.666667        95.000000        145.333333     75.000000  ...
# ...

# %%
#Skewiness and Kurtosis
print("Skewiness: %f" %df['Age'].skew())
print("Kurtosis: %f" %df['Age'].dropna().kurt())
# Out:
# Skewiness: 1.732051
# Kurtosis: nan

# %% [markdown]
# ## Corelation Analysis

# %%
pd.read_csv(r"C:\Users\ELIAS\Desktop\Oasis infobyte\Dataset\ifood_df.csv")
df=pd.read_csv(r"C:\Users\ELIAS\Desktop\Oasis infobyte\Dataset\ifood_df.csv")
df.drop(columns=['Z_CostContact', 'Z_Revenue'], inplace=True )

# %%
#Classification
cols_demographics = ['Income','Age']
cols_children = ['Kidhome', 'Teenhome']

Data_corr= df[['MntTotal'] + cols_demographics+ cols_children]. dropna().corr()
plt.figure(figsize= (10,6))
sns.heatmap(Data_corr,annot= True, cmap='coolwarm', linewidth= 0.5)
plt.title('Correlation Map MntTotal')
plt.show()

# %%
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Marital Status

# %%
#Marital Status(Single, Married, Together, Divorced, Widow, Unknown)
def get_marital_status(row):
    if row['marital_Single']==1:
        return 'Single'
    elif row['marital_Married']==1:
        return 'Married'
    elif row['marital_Together']==1:
        return 'Together'
    elif row['marital_Divorced']==1:
        return 'Divorced'
    elif row['marital_Widow']==1:
        return 'Widow'
    else:
        return 'Unknown'
    
df['Marital_status']= df.apply(get_marital_status, axis=1)

# %%
df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Widow  \
# 0              172                88            88  ...              0
# 1                2                 1             6  ...              0
# 2              111                21            42  ...              0
# 3               10                 3             5  ...              0
# 4               46                27            15  ...              0
#
#    education_2n Cycle  education_Basic  education_Graduation  \
# ...

# %%
#plot of Mnt total in relations to marital status
plt.figure(figsize= (8,6))
sns.boxplot(data=df, y= 'MntTotal', x='Marital_status', palette= 'viridis' )
plt.title('Boxplot of Marital Status', fontweight= 'bold', fontsize=12)
plt.xlabel('Marital_status', fontweight= 'bold')
plt.ylabel('MntTotal', fontweight= 'bold')
plt.show()
# Out:
# <ipython-input-20-e856536a6d11>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, y= 'MntTotal', x='Marital_status', palette= 'viridis' )

# %%
#Relationship Status
def get_in_relationship(row):
    if row['marital_Married']==1:
        return 1
    elif row['marital_Together']==1:
        return 1
    else:
        return 0

df['In_Relationship']=df.apply(get_in_relationship, axis=1)

# %%
df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  education_2n Cycle  \
# 0              172                88            88  ...                   0
# 1                2                 1             6  ...                   0
# 2              111                21            42  ...                   0
# 3               10                 3             5  ...                   0
# 4               46                27            15  ...                   0
#
# ...

# %% [markdown]
# # Cluster and K-Means model

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
cols_for_clustering= ['Income', 'MntTotal', 'In_Relationship']
df_scaled=df.copy()
df_scaled[cols_for_clustering]=scaler.fit_transform(df[cols_for_clustering])
df_scaled[cols_for_clustering].describe()
# Out:
#              Income      MntTotal  In_Relationship
# count  2.205000e+03  2.205000e+03     2.205000e+03
# mean   2.255691e-17 -3.705778e-17     6.444832e-17
# std    1.000227e+00  1.000227e+00     1.000227e+00
# min   -2.409272e+00 -9.704038e-01    -1.347625e+00
# 25%   -7.932106e-01 -8.800957e-01    -1.347625e+00
# 50%   -1.618161e-02 -3.816642e-01     7.420464e-01
# 75%    8.044529e-01  6.968235e-01     7.420464e-01
# max    2.999363e+00  3.348757e+00     7.420464e-01

# %%
#Principal Component Analysis(PCA)
from sklearn import decomposition
pca= decomposition.PCA(n_components=2)
pca_res=pca.fit_transform(df[cols_for_clustering])
df_scaled['pc1']=pca_res[:,0]
df_scaled['pc2']=pca_res[:,1]

# %%
#Elbow Method
X = df_scaled[cols_for_clustering]
inertia_list = []
for K in range(2,10):
    inertia = KMeans(n_clusters=K, random_state=7).fit(X).inertia_
    inertia_list.append(inertia)

# %%
color= (54/255, 113/255, 130/255)
plt.figure(figsize= (10,8))
plt.plot(range(2,10), inertia_list, color= 'brown')
plt.title('Inertia vs number of clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
#Silhoutte Score Analysis
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
silhouette_list=[]
for k in range(2,10):
    model=KMeans(n_clusters=k, random_state=7)
    clusters=model.fit_predict(X)
    s_avg=silhouette_score(X,clusters)
    silhouette_list.append(s_avg)
    
plt.figure(figsize=(10,8))
plt.plot(range(2,10), silhouette_list, color= 'pink')
plt.title('Silhouette score Vs Clusters(k)')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# The highest score is 4 clusters

# %%
model=KMeans(n_clusters=4, random_state=7)
model.fit(df_scaled[cols_for_clustering])
df_scaled['Cluster']=model.predict(df_scaled[cols_for_clustering])

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='pc1', y='pc2', data=df_scaled, palette='viridis', hue= 'Cluster')
plt.title('Scattered plot of Clusters')
plt.xlabel('Principal component 1')
plt.ylabel('Principal Component 2')
plt.legend(title= 'Clusters')

# %%
df['Cluster']=df_scaled.Cluster
df.groupby('Cluster')[cols_for_clustering].mean()
# Out:
#                Income     MntTotal  In_Relationship
# Cluster
# 0        37892.819883   158.463158              1.0
# 1        71846.901235  1149.742504              1.0
# 2        37332.339956   150.761589              0.0
# 3        72059.439394  1167.306061              0.0

# %%
cols_mnt = ['MntTotal', 'MntRegularProds','MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
mnt_df=df.groupby('Cluster')[cols_mnt].mean().reset_index()
mnt_df.head(10)
# Out:
#    Cluster     MntTotal  MntRegularProds    MntWines  MntFruits  \
# 0        0   158.463158       133.962573   92.046784   7.640936
# 1        1  1149.742504      1078.716049  624.382716  52.700176
# 2        2   150.761589       125.662252   85.450331   7.832230
# 3        3  1167.306061      1092.893939  617.148485  55.324242
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds
# 0        39.438596        11.423392          7.913450     24.500585
# 1       342.162257        75.615520         54.881834     71.026455
# 2        38.774834        10.971302          7.732892     25.099338
# 3       361.278788        77.703030         55.851515     74.412121

# %%
melted_df=pd.melt(mnt_df, id_vars="Cluster", var_name="Product", value_name="Consumption")
plt.figure(figsize=(10,6))
sns.barplot(data=melted_df, x='Cluster', y='Consumption', hue='Product',palette='viridis' )
plt.title("Product consumption by cluster")
plt.ylabel('Product consumption')
plt.xlabel('Cluster')
plt.legend(title="Product", loc= "upper left")
plt.show()

# %%
#Cluster sizes for MntTotal
Cluster_sizes=df.groupby('Cluster')[['MntTotal']].count().reset_index()
plt.figure(figsize=(10,6))
sns.barplot(data=Cluster_sizes, y='MntTotal', x='Cluster', palette= 'viridis')
plt.title('Cluster sizes for MntTotal', fontsize=14)
plt.ylabel('MntTotal')
plt.xlabel('Cluster')
# Out:
# <ipython-input-33-c7827c24e62e>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=Cluster_sizes, y='MntTotal', x='Cluster', palette= 'viridis')
# Text(0.5, 0, 'Cluster')

# %%
total_rows = len(df)
Cluster_sizes['Share%'] = round(Cluster_sizes['MntTotal'] / total_rows*100,0)
Cluster_sizes.head()
# Out:
#    Cluster  MntTotal  Share%
# 0        0       855    39.0
# 1        1       567    26.0
# 2        2       453    21.0
# 3        3       330    15.0

# %%
#Income by cluster

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, hue= 'Cluster', y='Income', palette= 'viridis')
plt.title('Income vs Cluster')
plt.xlabel('Cluster(k)')
plt.ylabel('Income')
plt.legend(title='Clusters', loc= 'upper left')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, hue= 'Cluster', x='Income', y= 'MntTotal', palette= 'viridis')
plt.title('Income vs Cluster')
plt.xlabel('Cluster(k)')
plt.ylabel('Income')
plt.legend(title='Clusters', loc= 'upper left')

# %%
plt.figure(figsize=(8,6))
sns. barplot(data=df, y='In_Relationship', x='Cluster', palette='viridis' )
plt.title('In Relationship vs Cluster')
plt.ylabel('In_relationship')
plt.xlabel('Clusters')
# Out:
# <ipython-input-38-77c55a007793>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns. barplot(data=df, y='In_Relationship', x='Cluster', palette='viridis' )
# Text(0.5, 0, 'Clusters')

# %% [markdown]
# ## Results:

# %% [markdown]
# Results
# This section contains the results of the K-means clustering analysis, which aimed to identify distinct customer segments based on the total amount of purchases they made (MntTotal). The analysis utilised 'Income' and 'In_relationship' features.

# %% [markdown]
# ## Optimal number of clusters
# The silhouette score analysis revealed a peak silhouette score for k=4

# %% [markdown]
# ## Cluster Characteristics
# Cluster 0: Low value customers in a relationship
# This cluster represents 39% of the customer base
# These customers have low income and they are in a relationship
#
# Cluster 1: High value customers in a relationship (either married or together)
# This cluster represents 26% of the customer base
# These customers have high income and they are in a relationship
#
# Cluster 2: Low value single customers
# This cluster represents 21% of the customer base
# These customers have low income and they are not in a relationship
#
# Cluster 3: High value  single customers
# This cluster represents 15% of the customer base
# These customers have high income and they are not in a relationship

# %% [markdown]
# ## Recommendation
# Cluster 0: Low value customers in relationship
# This cluster has the highest percentage of our customers (39%).
# Family offers and discounts may influence these customers to make more purchases
#
# Cluster 1: High value customers in relationship (either married or together)
# Preliminary analysis showed that high income customers buy more wines and fruits.
# A tailored campaign to promote high quality wines may bring good results.
# This cluster contains customers in relationship, family-oriented promo-images should be quite effective for this audience.
#
# Cluster 2: Low value single customers
# Promos with discounts and coupons may bring good results for this targeted group.
# Loyalty program may stimulate these customers to purchase more often.
#
# Cluster 3: High value single customers
# Similar to the Cluster 0, these customers buy a lot of wines and fruits.
# This cluster contains single customers. Promo images with friends, parties or single trips may be more efficient for single customers
